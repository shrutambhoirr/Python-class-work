# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Documents'

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1= pd.read_csv('iris.csv')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1 = pd.read_csv(r"iris.csv")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
 pd.read_excel(r"iris1.xlsx" , sheet_name="Sheet1", header = None)
# Out:
#              0
# 0      species
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
# 150  virginica
#
# [151 rows x 1 columns]

# %%
 pd.read_excel(r"iris1.xlsx" , sheet_name="Sheet1", header = None, names = ['A','B','C','D','E','F'])
# Out:
#              A   B   C   D   E   F
# 0      species NaN NaN NaN NaN NaN
# 1       setosa NaN NaN NaN NaN NaN
# 2       setosa NaN NaN NaN NaN NaN
# 3       setosa NaN NaN NaN NaN NaN
# 4       setosa NaN NaN NaN NaN NaN
# ..         ...  ..  ..  ..  ..  ..
# 146  virginica NaN NaN NaN NaN NaN
# 147  virginica NaN NaN NaN NaN NaN
# 148  virginica NaN NaN NaN NaN NaN
# 149  virginica NaN NaN NaN NaN NaN
# 150  virginica NaN NaN NaN NaN NaN
#
# [151 rows x 6 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df1=pd.read_csv('iris.csv')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_csv('iris.csv',names=['Age of patient','Patient year od operation', 'Number','Survival status'])
# Out:
#              Age of patient Patient year od operation       Number  \
# sepal_length    sepal_width              petal_length  petal_width
# 5.1                     3.5                       1.4          0.2
# 4.9                     3.0                       1.4          0.2
# 4.7                     3.2                       1.3          0.2
# 4.6                     3.1                       1.5          0.2
# ...                     ...                       ...          ...
# 6.7                     3.0                       5.2          2.3
# 6.3                     2.5                       5.0          1.9
# 6.5                     3.0                       5.2          2.0
# 6.2                     3.4                       5.4          2.3
# 5.9                     3.0                       5.1          1.8
#
#              Survival status
# sepal_length         species
# 5.1                   setosa
# 4.9                   setosa
# 4.7                   setosa
# ...

# %%
pd.read_csv('iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_csv('iris.csv',sep=',')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/shrutambhoirr/Python-class-work/main/iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a = pd.read_html("https://en.wikipedia.org/wiki/Minnesota")

# %%
a
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nickname(s): Land of 10,000 Lakes;North Star S...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                      Largest metro and urban areas
#  12                                         Government
#  13                                         • Governor
#  14                              • Lieutenant Governor
#  15                                        Legislature
# ...

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 31

# %%
a[0]
# Out:
#                                             Minnesota  \
# 0                                               State
# 1   .mw-parser-output .ib-settlement-cols{text-ali...
# 2   Nickname(s): Land of 10,000 Lakes;North Star S...
# 3   Motto: L'Étoile du Nord (French: The Star of t...
# 4                           Anthem: "Hail! Minnesota"
# 5   Map of the United States with Minnesota highli...
# 6                                             Country
# 7                                    Before statehood
# 8                               Admitted to the Union
# 9                                             Capital
# 10                                       Largest city
# 11                      Largest metro and urban areas
# 12                                         Government
# 13                                         • Governor
# 14                              • Lieutenant Governor
# 15                                        Legislature
# ...

# %%
 df = pd.read_excel(r"iris1.xlsx")
 df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df1 = df['sepal_length']

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df[['sepal_width','petal_width','species']]
# Out:
#      sepal_width  petal_width    species
# 0            3.5          0.2     setosa
# 1            3.0          0.2     setosa
# 2            3.2          0.2     setosa
# 3            3.1          0.2     setosa
# 4            3.6          0.2     setosa
# ..           ...          ...        ...
# 145          3.0          2.3  virginica
# 146          2.5          1.9  virginica
# 147          3.0          2.0  virginica
# 148          3.4          2.3  virginica
# 149          3.0          1.8  virginica
#
# [150 rows x 3 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species          True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# species    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['species'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
df.dtypes[df.dtypes == 'float']
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# dtype: object

# %%
df[df.dtypes[df.dtypes == 'float'].index]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df[df.dtypes[df.dtypes == 'float'].index].describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]>

# %%
df['species'] [1:14:2]
# Out:
# 1     setosa
# 3     setosa
# 5     setosa
# 7     setosa
# 9     setosa
# 11    setosa
# 13    setosa
# Name: species, dtype: object

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['category']='Sheet1'

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species category
# 0             5.1          3.5           1.4          0.2     setosa   Sheet1
# 1             4.9          3.0           1.4          0.2     setosa   Sheet1
# 2             4.7          3.2           1.3          0.2     setosa   Sheet1
# 3             4.6          3.1           1.5          0.2     setosa   Sheet1
# 4             5.0          3.6           1.4          0.2     setosa   Sheet1
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica   Sheet1
# 146           6.3          2.5           5.0          1.9  virginica   Sheet1
# 147           6.5          3.0           5.2          2.0  virginica   Sheet1
# 148           6.2          3.4           5.4          2.3  virginica   Sheet1
# 149           5.9          3.0           5.1          1.8  virginica   Sheet1
#
# [150 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'category'],
#       dtype='object')

# %%
df['species'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: species, Length: 150, dtype: bool

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species category
# 0             5.1          3.5           1.4          0.2     setosa   Sheet1
# 1             4.9          3.0           1.4          0.2     setosa   Sheet1
# 2             4.7          3.2           1.3          0.2     setosa   Sheet1
# 3             4.6          3.1           1.5          0.2     setosa   Sheet1
# 4             5.0          3.6           1.4          0.2     setosa   Sheet1
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica   Sheet1
# 146           6.3          2.5           5.0          1.9  virginica   Sheet1
# 147           6.5          3.0           5.2          2.0  virginica   Sheet1
# 148           6.2          3.4           5.4          2.3  virginica   Sheet1
# 149           5.9          3.0           5.1          1.8  virginica   Sheet1
#
# [150 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'category'],
#       dtype='object')

# %%
df['species']== max(df['species'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: species, Length: 150, dtype: bool

# %%
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df[df['species']== 'cotton']
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species, category]
# Index: []

# %%
len(df[df['species']== 'cotton'])
# Out:
# 0

# %%
df[df['sepal_length']>4.5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species category
# 0             5.1          3.5           1.4          0.2     setosa   Sheet1
# 1             4.9          3.0           1.4          0.2     setosa   Sheet1
# 2             4.7          3.2           1.3          0.2     setosa   Sheet1
# 3             4.6          3.1           1.5          0.2     setosa   Sheet1
# 4             5.0          3.6           1.4          0.2     setosa   Sheet1
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica   Sheet1
# 146           6.3          2.5           5.0          1.9  virginica   Sheet1
# 147           6.5          3.0           5.2          2.0  virginica   Sheet1
# 148           6.2          3.4           5.4          2.3  virginica   Sheet1
# 149           5.9          3.0           5.1          1.8  virginica   Sheet1
#
# [145 rows x 6 columns]

# %%
df[df['sepal_length']>4.5]['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 145, dtype: float64

# %%
(df['sepal_length']>4.5) & (df['species']== 'setosa')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# category         object
# dtype: object

# %%
pd.read_excel("iris1.xlsx")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = pd.read_excel("iris1.xlsx")

# %%
date = pd.to_datetime(df['sepal_length'])

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['sepal_length'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#              converted_order_date
# 0   1970-01-01 00:00:00.000000005
# 1   1970-01-01 00:00:00.000000004
# ...

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#            converted_order_date  order_date_year
# 0 1970-01-01 00:00:00.000000005             1970
# 1 1970-01-01 00:00:00.000000004             1970
# 2 1970-01-01 00:00:00.000000004             1970
# 3 1970-01-01 00:00:00.000000004             1970
# 4 1970-01-01 00:00:00.000000005             1970

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#              converted_order_date  order_date_year
# 145 1970-01-01 00:00:00.000000006             1970
# 146 1970-01-01 00:00:00.000000006             1970
# 147 1970-01-01 00:00:00.000000006             1970
# 148 1970-01-01 00:00:00.000000006             1970
# 149 1970-01-01 00:00:00.000000005             1970

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#              converted_order_date  order_date_year  order_date_month
# 145 1970-01-01 00:00:00.000000006             1970                 1
# 146 1970-01-01 00:00:00.000000006             1970                 1
# 147 1970-01-01 00:00:00.000000006             1970                 1
# 148 1970-01-01 00:00:00.000000006             1970                 1
# 149 1970-01-01 00:00:00.000000005             1970                 1

# %%
df['order_date_week'] = df['converted_order_date'].dt.isocalendar().week

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species category  \
# 145           6.7          3.0           5.2          2.3  virginica   Sheet1
# 146           6.3          2.5           5.0          1.9  virginica   Sheet1
# 147           6.5          3.0           5.2          2.0  virginica   Sheet1
# 148           6.2          3.4           5.4          2.3  virginica   Sheet1
# 149           5.9          3.0           5.1          1.8  virginica   Sheet1
#
#              converted_order_date  order_date_year  order_date_month  \
# 145 1970-01-01 00:00:00.000000006             1970                 1
# 146 1970-01-01 00:00:00.000000006             1970                 1
# 147 1970-01-01 00:00:00.000000006             1970                 1
# 148 1970-01-01 00:00:00.000000006             1970                 1
# 149 1970-01-01 00:00:00.000000005             1970                 1
#
#      order_date_week
# 145                1
# 146                1
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species category  \
# 0           5.1          3.5           1.4          0.2  setosa   Sheet1
# 1           4.9          3.0           1.4          0.2  setosa   Sheet1
# 2           4.7          3.2           1.3          0.2  setosa   Sheet1
# 3           4.6          3.1           1.5          0.2  setosa   Sheet1
# 4           5.0          3.6           1.4          0.2  setosa   Sheet1
#
#            converted_order_date  order_date_year  order_date_month  \
# 0 1970-01-01 00:00:00.000000005             1970                 1
# 1 1970-01-01 00:00:00.000000004             1970                 1
# 2 1970-01-01 00:00:00.000000004             1970                 1
# 3 1970-01-01 00:00:00.000000004             1970                 1
# 4 1970-01-01 00:00:00.000000005             1970                 1
#
#    order_date_week
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
df[['converted_order_date', 'order_date_week']]
# Out:
#              converted_order_date  order_date_week
# 0   1970-01-01 00:00:00.000000005                1
# 1   1970-01-01 00:00:00.000000004                1
# 2   1970-01-01 00:00:00.000000004                1
# 3   1970-01-01 00:00:00.000000004                1
# 4   1970-01-01 00:00:00.000000005                1
# ..                            ...              ...
# 145 1970-01-01 00:00:00.000000006                1
# 146 1970-01-01 00:00:00.000000006                1
# 147 1970-01-01 00:00:00.000000006                1
# 148 1970-01-01 00:00:00.000000006                1
# 149 1970-01-01 00:00:00.000000005                1
#
# [150 rows x 2 columns]

# %%
df['order_date_year']==2023
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: order_date_year, Length: 150, dtype: bool

# %%
df['order_date_month'].value_counts()
# Out:
# 1    150
# Name: order_date_month, dtype: int64

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species category  \
# 0             5.1          3.5           1.4          0.2     setosa   Sheet1
# 1             4.9          3.0           1.4          0.2     setosa   Sheet1
# 2             4.7          3.2           1.3          0.2     setosa   Sheet1
# 3             4.6          3.1           1.5          0.2     setosa   Sheet1
# 4             5.0          3.6           1.4          0.2     setosa   Sheet1
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica   Sheet1
# 146           6.3          2.5           5.0          1.9  virginica   Sheet1
# 147           6.5          3.0           5.2          2.0  virginica   Sheet1
# 148           6.2          3.4           5.4          2.3  virginica   Sheet1
# 149           5.9          3.0           5.1          1.8  virginica   Sheet1
#
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species category  \
# 0           5.1          3.5           1.4          0.2  setosa   Sheet1
# 1           4.9          3.0           1.4          0.2  setosa   Sheet1
# 2           4.7          3.2           1.3          0.2  setosa   Sheet1
# 3           4.6          3.1           1.5          0.2  setosa   Sheet1
# 4           5.0          3.6           1.4          0.2  setosa   Sheet1
#
#            converted_order_date  order_date_year  order_date_month  \
# 0 1970-01-01 00:00:00.000000005             1970                 1
# 1 1970-01-01 00:00:00.000000004             1970                 1
# 2 1970-01-01 00:00:00.000000004             1970                 1
# 3 1970-01-01 00:00:00.000000004             1970                 1
# 4 1970-01-01 00:00:00.000000005             1970                 1
#
#    order_date_week
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species category  \
# 0           5.1          3.5           1.4          0.2  setosa   Sheet1
# 1           4.9          3.0           1.4          0.2  setosa   Sheet1
# 2           4.7          3.2           1.3          0.2  setosa   Sheet1
# 3           4.6          3.1           1.5          0.2  setosa   Sheet1
# 4           5.0          3.6           1.4          0.2  setosa   Sheet1
#
#            converted_order_date  order_date_year  order_date_month  \
# 0 1970-01-01 00:00:00.000000005             1970                 1
# 1 1970-01-01 00:00:00.000000004             1970                 1
# 2 1970-01-01 00:00:00.000000004             1970                 1
# 3 1970-01-01 00:00:00.000000004             1970                 1
# 4 1970-01-01 00:00:00.000000005             1970                 1
#
#    order_date_week
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
df.loc[2:10:2]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species category  \
# 2            4.7          3.2           1.3          0.2  setosa   Sheet1
# 4            5.0          3.6           1.4          0.2  setosa   Sheet1
# 6            4.6          3.4           1.4          0.3  setosa   Sheet1
# 8            4.4          2.9           1.4          0.2  setosa   Sheet1
# 10           5.4          3.7           1.5          0.2  setosa   Sheet1
#
#             converted_order_date  order_date_year  order_date_month  \
# 2  1970-01-01 00:00:00.000000004             1970                 1
# 4  1970-01-01 00:00:00.000000005             1970                 1
# 6  1970-01-01 00:00:00.000000004             1970                 1
# 8  1970-01-01 00:00:00.000000004             1970                 1
# 10 1970-01-01 00:00:00.000000005             1970                 1
#
#     order_date_week
# 2                 1
# 4                 1
# 6                 1
# 8                 1
# ...

# %%
df.loc[0:3, ['sepal_length', 'sepal_width','petal_length']]
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5

# %%
df.iloc[0:5,4:7]
# Out:
#   species category          converted_order_date
# 0  setosa   Sheet1 1970-01-01 00:00:00.000000005
# 1  setosa   Sheet1 1970-01-01 00:00:00.000000004
# 2  setosa   Sheet1 1970-01-01 00:00:00.000000004
# 3  setosa   Sheet1 1970-01-01 00:00:00.000000004
# 4  setosa   Sheet1 1970-01-01 00:00:00.000000005

# %%
#loc=named indexes, iloc default indexes

# %%
df.iloc[2:6,4:7]
# Out:
#   species category          converted_order_date
# 2  setosa   Sheet1 1970-01-01 00:00:00.000000004
# 3  setosa   Sheet1 1970-01-01 00:00:00.000000004
# 4  setosa   Sheet1 1970-01-01 00:00:00.000000005
# 5  setosa   Sheet1 1970-01-01 00:00:00.000000005

# %%
df.dtypes
# Out:
# sepal_length                   float64
# sepal_width                    float64
# petal_length                   float64
# petal_width                    float64
# species                         object
# category                        object
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# order_date_month                 int64
# order_date_week                 UInt32
# dtype: object

# %%
df2=df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')] .index]

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  order_date_year  \
# 0             5.1          3.5           1.4          0.2             1970
# 1             4.9          3.0           1.4          0.2             1970
# 2             4.7          3.2           1.3          0.2             1970
# 3             4.6          3.1           1.5          0.2             1970
# 4             5.0          3.6           1.4          0.2             1970
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3             1970
# 146           6.3          2.5           5.0          1.9             1970
# 147           6.5          3.0           5.2          2.0             1970
# 148           6.2          3.4           5.4          2.3             1970
# 149           5.9          3.0           5.1          1.8             1970
#
#      order_date_month
# 0                   1
# ...

# %%
df3 = df2[df2 == 1]

# %%
df3.dropna(axis = 1)
# Out:
#      order_date_month
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...
# 145                 1
# 146                 1
# 147                 1
# 148                 1
# 149                 1
#
# [150 rows x 1 columns]

# %%
df3.dropna(thresh=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  order_date_year  \
# 0             NaN          NaN           NaN          NaN              NaN
# 1             NaN          NaN           NaN          NaN              NaN
# 2             NaN          NaN           NaN          NaN              NaN
# 3             NaN          NaN           NaN          NaN              NaN
# 4             NaN          NaN           NaN          NaN              NaN
# ..            ...          ...           ...          ...              ...
# 145           NaN          NaN           NaN          NaN              NaN
# 146           NaN          NaN           NaN          NaN              NaN
# 147           NaN          NaN           NaN          NaN              NaN
# 148           NaN          NaN           NaN          NaN              NaN
# 149           NaN          NaN           NaN          NaN              NaN
#
#      order_date_month
# 0                   1
# ...

# %%
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  order_date_year  \
# 0             NaN          NaN           NaN          NaN              NaN
# 1             NaN          NaN           NaN          NaN              NaN
# 2             NaN          NaN           NaN          NaN              NaN
# 3             NaN          NaN           NaN          NaN              NaN
# 4             NaN          NaN           NaN          NaN              NaN
# ..            ...          ...           ...          ...              ...
# 145           NaN          NaN           NaN          NaN              NaN
# 146           NaN          NaN           NaN          NaN              NaN
# 147           NaN          NaN           NaN          NaN              NaN
# 148           NaN          NaN           NaN          NaN              NaN
# 149           NaN          NaN           NaN          NaN              NaN
#
#      order_date_month
# 0                   1
# ...

# %%
df3.fillna(value=3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  order_date_year  \
# 0             3.0          3.0           3.0          3.0              3.0
# 1             3.0          3.0           3.0          3.0              3.0
# 2             3.0          3.0           3.0          3.0              3.0
# 3             3.0          3.0           3.0          3.0              3.0
# 4             3.0          3.0           3.0          3.0              3.0
# ..            ...          ...           ...          ...              ...
# 145           3.0          3.0           3.0          3.0              3.0
# 146           3.0          3.0           3.0          3.0              3.0
# 147           3.0          3.0           3.0          3.0              3.0
# 148           3.0          3.0           3.0          3.0              3.0
# 149           3.0          3.0           3.0          3.0              3.0
#
#      order_date_month
# 0                   1
# ...

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  order_date_year  \
# 0             5.1          3.5           1.4          0.2             1970
# 1             4.9          3.0           1.4          0.2             1970
# 2             4.7          3.2           1.3          0.2             1970
# 3             4.6          3.1           1.5          0.2             1970
# 4             5.0          3.6           1.4          0.2             1970
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3             1970
# 146           6.3          2.5           5.0          1.9             1970
# 147           6.5          3.0           5.2          2.0             1970
# 148           6.2          3.4           5.4          2.3             1970
# 149           5.9          3.0           5.1          1.8             1970
#
#      order_date_month
# 0                   1
# ...

# %%
df3 = df2.groupby('petal_length')

# %%
df3

# %%
df2.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'order_date_year', 'order_date_month'],
#       dtype='object')

# %%
df.dtypes
# Out:
# sepal_length                   float64
# sepal_width                    float64
# petal_length                   float64
# petal_width                    float64
# species                         object
# category                        object
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# order_date_month                 int64
# order_date_week                 UInt32
# dtype: object

# %%
data = {'name' : ['shrutam', 'ram','sham','kam'], 
       'salary': [100, 200, 300, 400],
       'email': ['shrutam@mes.ac.in', 'ram@mes.ac.in', 'sham@mes.ac.in','kam@mes.ac.in'],
       'addr': ['wer', 'ert', 'ert', 'weew']}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  salary              email  addr
# 0  shrutam     100  shrutam@mes.ac.in   wer
# 1      ram     200      ram@mes.ac.in   ert
# 2     sham     300     sham@mes.ac.in   ert
# 3      kam     400      kam@mes.ac.in  weew

# %%
pd.DataFrame(data,index = [4,5,6,7])
# Out:
#       name  salary              email  addr
# 4  shrutam     100  shrutam@mes.ac.in   wer
# 5      ram     200      ram@mes.ac.in   ert
# 6     sham     300     sham@mes.ac.in   ert
# 7      kam     400      kam@mes.ac.in  weew

# %%
df.loc[4:7]
# Out:
# Empty DataFrame
# Columns: [name, salary, email, addr]
# Index: []

# %%
df.iloc[1:3]
# Out:
#    name  salary           email addr
# 1   ram     200   ram@mes.ac.in  ert
# 2  sham     300  sham@mes.ac.in  ert

# %%
pd.DataFrame(data,index = [0,1,2,3])
# Out:
#       name  salary              email  addr
# 0  shrutam     100  shrutam@mes.ac.in   wer
# 1      ram     200      ram@mes.ac.in   ert
# 2     sham     300     sham@mes.ac.in   ert
# 3      kam     400      kam@mes.ac.in  weew

# %%
data1 = {'pf_num':[12,23,34,54],
        'incometax': [132,435,452,123],
         'mobile': [1324123,2314123,341,23423],
         'courses':['ds','big data', 'dl','python']}

# %%
df1 = pd.DataFrame(data1)

# %% [markdown]
# df1

# %%
df1
# Out:
#    pf_num  incometax   mobile   courses
# 0      12        132  1324123        ds
# 1      23        435  2314123  big data
# 2      34        452      341        dl
# 3      54        123    23423    python

# %%
pd.concat([df,df1])
# Out:
#       name  salary              email  addr  pf_num  incometax     mobile  \
# 0  shrutam   100.0  shrutam@mes.ac.in   wer     NaN        NaN        NaN
# 1      ram   200.0      ram@mes.ac.in   ert     NaN        NaN        NaN
# 2     sham   300.0     sham@mes.ac.in   ert     NaN        NaN        NaN
# 3      kam   400.0      kam@mes.ac.in  weew     NaN        NaN        NaN
# 0      NaN     NaN                NaN   NaN    12.0      132.0  1324123.0
# 1      NaN     NaN                NaN   NaN    23.0      435.0  2314123.0
# 2      NaN     NaN                NaN   NaN    34.0      452.0      341.0
# 3      NaN     NaN                NaN   NaN    54.0      123.0    23423.0
#
#     courses
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 0        ds
# 1  big data
# 2        dl
# 3    python

# %%
pd.concat([df,df1], axis=1)
# Out:
#       name  salary              email  addr  pf_num  incometax   mobile  \
# 0  shrutam     100  shrutam@mes.ac.in   wer      12        132  1324123
# 1      ram     200      ram@mes.ac.in   ert      23        435  2314123
# 2     sham     300     sham@mes.ac.in   ert      34        452      341
# 3      kam     400      kam@mes.ac.in  weew      54        123    23423
#
#     courses
# 0        ds
# 1  big data
# 2        dl
# 3    python

# %%
pd.concat([df,df1], axis=0)
# Out:
#       name  salary              email  addr  pf_num  incometax     mobile  \
# 0  shrutam   100.0  shrutam@mes.ac.in   wer     NaN        NaN        NaN
# 1      ram   200.0      ram@mes.ac.in   ert     NaN        NaN        NaN
# 2     sham   300.0     sham@mes.ac.in   ert     NaN        NaN        NaN
# 3      kam   400.0      kam@mes.ac.in  weew     NaN        NaN        NaN
# 0      NaN     NaN                NaN   NaN    12.0      132.0  1324123.0
# 1      NaN     NaN                NaN   NaN    23.0      435.0  2314123.0
# 2      NaN     NaN                NaN   NaN    34.0      452.0      341.0
# 3      NaN     NaN                NaN   NaN    54.0      123.0    23423.0
#
#     courses
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 0        ds
# 1  big data
# 2        dl
# 3    python

# %%
data2 = {'0' : ['shrutam', 'kam','ram','sham'], 
       '1': [100, 200, 300, 400],
       '2': ['shrutam@mes.ac.in', 'kam@mes.ac.in', 'ram@mes.ac.in','sham@mes.ac.in'],
       '3': ['wer', 'ert', 'ert', 'weew']}

# %%
data3 = {'0':[12,23,34,54],
        '1': [132,435,452,123],
         '2': [1324123,2314123,341,23423],
         '3':['ds','big data', 'dl','python']}

# %%
df3=pd.DataFrame(data2)

# %%
df4=pd.DataFrame(data3)

# %%
pd.concat([df3,df4])
# Out:
#          0    1                  2         3
# 0  shrutam  100  shrutam@mes.ac.in       wer
# 1      kam  200      kam@mes.ac.in       ert
# 2      ram  300      ram@mes.ac.in       ert
# 3     sham  400     sham@mes.ac.in      weew
# 0       12  132            1324123        ds
# 1       23  435            2314123  big data
# 2       34  452                341        dl
# 3       54  123              23423    python

# %%
data5 = {'emp_id':[101,102,103,104],
        'salary':[12,45,53,45],
        'providentfund':[12312,3432,234,535]}

# %%
data6 = {'emp_id': [101,102,103,104],
       'mobile_no':[12321,3423,2432,2412],
       'house_no':[12312,234,2344,123]}

# %%
df5 = pd.DataFrame(data5)
df5
# Out:
#    emp_id  salary  providentfund
# 0     101      12          12312
# 1     102      45           3432
# 2     103      53            234
# 3     104      45            535

# %%
df6 = pd.DataFrame(data6)

# %%
df6
# Out:
#    emp_id  mobile_no  house_no
# 0     101      12321     12312
# 1     102       3423       234
# 2     103       2432      2344
# 3     104       2412       123

# %%
df6
# Out:
#    emp_id  mobile_no  house_no
# 0     101      12321     12312
# 1     102       3423       234
# 2     103       2432      2344
# 3     104       2412       123

# %%
pd.merge(df5,df6)
# Out:
#    emp_id  salary  providentfund  mobile_no  house_no
# 0     101      12          12312      12321     12312
# 1     102      45           3432       3423       234
# 2     103      53            234       2432      2344
# 3     104      45            535       2412       123

# %%
pd.merge(df6,df5, how = 'left')
# Out:
#    emp_id  mobile_no  house_no  salary  providentfund
# 0     101      12321     12312      12          12312
# 1     102       3423       234      45           3432
# 2     103       2432      2344      53            234
# 3     104       2412       123      45            535

# %%
pd.merge(df6,df5, how = 'right')
# Out:
#    emp_id  mobile_no  house_no  salary  providentfund
# 0     101      12321     12312      12          12312
# 1     102       3423       234      45           3432
# 2     103       2432      2344      53            234
# 3     104       2412       123      45            535

# %%
data7 = {'emp_id1':[101,102,103,104],
        'salary':[12,45,53,45],
        'providentfund':[12312,3432,234,535]}
data8 = {'emp_id2': [101,102,103,104],
       'mobile_no':[12321,3423,2432,2412],
       'house_no':[12312,234,2344,123]}

# %%
df7 = pd.DataFrame(data7)
df8 = pd.DataFrame(data8)

# %%
df7
# Out:
#    emp_id1  salary  providentfund
# 0      101      12          12312
# 1      102      45           3432
# 2      103      53            234
# 3      104      45            535

# %%
pd.merge(df7,df8, left_on='emp_id1', right_on='emp_id2', how = 'inner')
# Out:
#    emp_id1  salary  providentfund  emp_id2  mobile_no  house_no
# 0      101      12          12312      101      12321     12312
# 1      102      45           3432      102       3423       234
# 2      103      53            234      103       2432      2344
# 3      104      45            535      104       2412       123

# %%
data9 = {'emp_id':[101,102,103,104],
        'salary':[12,45,53,45],
        'providentfund':[12312,3432,234,535]}
data10 = {'emp_id': [101,102,104,103],
       'mobile_no':[12321,3423,2432,2412],
       'house_no':[12312,234,2344,123]}

# %%
df9 = pd.DataFrame(data9)
df10 = pd.DataFrame(data10)

# %%
df = pd.merge(df9,df10, on = ['emp_id'])

# %%
df = pd.read_csv("iris.csv")

# %%
df[2000:3000]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
def profit_flag(a):
    if a>0:
        return 'positive'
    else :
        return 'negative'

# %%
profit_flag(-23)
# Out:
# 'negative'

# %%
profit_flag(23)
# Out:
# 'positive'

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
def hour_flag(a):
    if a>10:
        return 'low'
    elif a>10 and a<20:
        return 'medium'
    else:
        return 'high'

# %%
df.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#week 6 starts from here

import numpy as np
a = np.array([2,3,4,5])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
np.array([[1,2,3],[3,4,5],[3,6,7]])
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [3, 6, 7]])

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind = 'area',alpha =0.1,stacked = False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length',y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y = 'petal_length', c='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_width',y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length', c='sepal_width',s=df['sepal_length']*10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length', gridsize=10,cmap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1,6,30)

# %%
y=np.linspace(-1,6,30)

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z = x+y

# %%
def sin_fun(x,y):
    return np.sin(np.sqrt(x**2+y**2))

# %%
z = sin_fun(x,y)

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)

# %%
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel("z")
# Out:
# Text(0.10787434422876366, 0.014452421710066993, 'z')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['petal_length'],df['petal_width'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('petal_length')
ax.set_zlabel("sepal_width")
# Out:
# Text(0.5, 0, 'sepal_width')

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[50:70].plot(kind = 'bar',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[50:70].plot(kind = 'barh',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['petal_length'].plot(kind='hist',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(20,10), color='#50DBB4', alpha=0.6)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\2559911492.py in <module>
# ----> 1 import cufflinks as cf
#       2 cf.go_offline()
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\4163631973.py in <module>
# ----> 1 df.iplot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(x='sepal_length', y='sepal_width', kind='scatter', mode = 'markers')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\3339971306.py in <module>
# ----> 1 df.iplot(x='sepal_length', y='sepal_width', kind='scatter', mode = 'markers')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(x='sepal_length', y='sepal_width', size = 'sepal_length',kind='bubble')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\4186623597.py in <module>
# ----> 1 df.iplot(x='sepal_length', y='sepal_width', size = 'sepal_length',kind='bubble')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(x='sepal_length', y='sepal_width', z = 'petal_length',size = 'sepal_length',kind='bubble3d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\3476493093.py in <module>
# ----> 1 df.iplot(x='sepal_length', y='sepal_width', z = 'petal_length',size = 'sepal_length',kind='bubble3d')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.iplot(x='total_bill',y='tip', kind = 'scatter', mode ='markers')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\2205355077.py in <module>
# ----> 1 df1.iplot(x='total_bill',y='tip', kind = 'scatter', mode ='markers')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
sns.relplot(x='total_bill', y='tip', data = df1, hue = 'size')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data = df1, col = 'sex')

# %%
sns.relplot(x='total_bill', y='tip', data = df1, col = 'time')

# %%
sns.relplot(x='sepal_length', y='sepal_width', data = df, col = 'species')

# %%
sns.relplot(x='total_bill', y='tip', data=df1, col='day')

# %%
sns.catplot(x='day', y='total_bill', data=df1)

# %%
sns.pairplot(df1)

# %%
df.scatter_matrix()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\3454576310.py in <module>
# ----> 1 df.scatter_matrix()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatter_matrix'

# %%
df1 = sns.load_dataset('tips')

# %%
sns.jointplot(x=df1.total_bill, y=df1.tip)

# %%
sns.pairplot(df1)

# %%
sns.regplot(x=df1.total_bill, y=df1.tip)
sns.set(rc={'figure.figsize':(20,10)})

# %%
df1

# %%
import plotly.express as px
fig = px.scatter(df1, x="total_bill", y="tip", color = "time")
fig.show()

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()

# %%
import plotly.express as px
fig = px.bar(df1, y="total_bill", x="sex", color = "smoker",barmode = "group")
fig.show()
